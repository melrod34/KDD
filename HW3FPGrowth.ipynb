# %%
import pandas as pd 
import numpy as np 
import plotly
import mlxtend

# %%
titanic = pd.read_csv("Titanic.csv")
titanic.shape
# Out:
# (2201, 4)

# %%
# Gather All Items of Each Transactions into Numpy Array
transaction = []
for i in range(0, titanic.shape[0]):
    for j in range(0, titanic.shape[1]):
        transaction.append(titanic.values[i,j])
# converting to numpy array
transaction = np.array(transaction)
print(transaction)
# Out:
# ['3rd' 'Male' 'Child' ... 'Female' 'Adult' 'Yes']

# %%
#  Transform Them a Pandas DataFrame
df = pd.DataFrame(transaction, columns=["items"])
# Put 1 to Each Item For Making Countable Table, to be able to perform Group By
df["incident_count"] = 1
df
# Out:
#        items  incident_count
# 0        3rd               1
# 1       Male               1
# 2      Child               1
# 3         No               1
# 4        3rd               1
# ...      ...             ...
# 8799     Yes               1
# 8800    Crew               1
# 8801  Female               1
# 8802   Adult               1
# 8803     Yes               1
#
# [8804 rows x 2 columns]

# %%
# Making a New Appropriate Pandas DataFrame for Visualizations
df_table = df.groupby("items").sum().sort_values("incident_count", ascending=False).reset_index()
df_table
# Out:
#     items  incident_count
# 0   Adult            2092
# 1    Male            1731
# 2      No            1490
# 3    Crew             885
# 4     Yes             711
# 5     3rd             706
# 6  Female             470
# 7     1st             325
# 8     2nd             285
# 9   Child             109

# %%
# Transform Every Transaction to Seperate List & Gather Them into Numpy Array
transaction2 = []
for i in range(titanic.shape[0]):
    transaction2.append([str(titanic.values[i,j]) for j in range(titanic.shape[1])])
# Out:
# [['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Male', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['3rd', 'Female', 'Child', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['1st', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['2nd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['3rd', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ['Crew', 'Male', 'Adult', 'No'],
#  ...]

# %%
transaction2 = np.array(transaction2)
transaction2
# Out:
# array([['3rd', 'Male', 'Child', 'No'],
#        ['3rd', 'Male', 'Child', 'No'],
#        ['3rd', 'Male', 'Child', 'No'],
#        ...,
#        ['Crew', 'Female', 'Adult', 'Yes'],
#        ['Crew', 'Female', 'Adult', 'Yes'],
#        ['Crew', 'Female', 'Adult', 'Yes']], dtype='<U6')

# %%
# importing the required module
from mlxtend.preprocessing import TransactionEncoder
# initializing the transactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transaction2).transform(transaction2)
te_ary
# Out:
# array([[False, False,  True, ...,  True,  True, False],
#        [False, False,  True, ...,  True,  True, False],
#        [False, False,  True, ...,  True,  True, False],
#        ...,
#        [False, False, False, ..., False, False,  True],
#        [False, False, False, ..., False, False,  True],
#        [False, False, False, ..., False, False,  True]])

# %%
dataset2 = pd.DataFrame(te_ary, columns=te.columns_)
# dataset after encoded
dataset2
# Out:
#         1st    2nd    3rd  Adult  Child   Crew  Female   Male     No    Yes
# 0     False  False   True  False   True  False   False   True   True  False
# 1     False  False   True  False   True  False   False   True   True  False
# 2     False  False   True  False   True  False   False   True   True  False
# 3     False  False   True  False   True  False   False   True   True  False
# 4     False  False   True  False   True  False   False   True   True  False
# ...     ...    ...    ...    ...    ...    ...     ...    ...    ...    ...
# 2196  False  False  False   True  False   True    True  False  False   True
# 2197  False  False  False   True  False   True    True  False  False   True
# 2198  False  False  False   True  False   True    True  False  False   True
# 2199  False  False  False   True  False   True    True  False  False   True
# 2200  False  False  False   True  False   True    True  False  False   True
#
# [2201 rows x 10 columns]

# %%
# select top 30 items
first30 = df_table["items"].head(30).values
# Extract Top 30
dataset3 = dataset2.loc[:,first30]
# shape of the dataset
dataset3.shape
# Out:
# (2201, 10)

# %%
#Importing Libraries
from mlxtend.frequent_patterns import fpgrowth
#running the fpgrowth algorithm
res=fpgrowth(dataset3,min_support=0.1, use_colnames=True)
res.head(10)
# Out:
#     support       itemsets
# 0  0.786461         (Male)
# 1  0.676965           (No)
# 2  0.320763          (3rd)
# 3  0.213539       (Female)
# 4  0.950477        (Adult)
# 5  0.147660          (1st)
# 6  0.129487          (2nd)
# 7  0.402090         (Crew)
# 8  0.323035          (Yes)
# 9  0.757383  (Male, Adult)

# %%
# importing required module
from mlxtend.frequent_patterns import association_rules
# creating asssociation rules
rules=association_rules(res, metric="confidence", min_threshold=0.7)
# printing association rules
rules
# Out:
#             antecedents        consequents  antecedent support  \
# 0                (Male)            (Adult)            0.786461
# 1               (Adult)             (Male)            0.950477
# 2                (Male)               (No)            0.786461
# 3                  (No)             (Male)            0.676965
# 4                  (No)            (Adult)            0.676965
# 5         (Male, Adult)               (No)            0.757383
# 6            (Male, No)            (Adult)            0.619718
# 7           (Adult, No)             (Male)            0.653339
# 8                (Male)        (Adult, No)            0.786461
# 9                  (No)      (Male, Adult)            0.676965
# 10                (3rd)               (No)            0.320763
# 11                (3rd)             (Male)            0.320763
# 12                (3rd)            (Adult)            0.320763
# 13         (Adult, 3rd)               (No)            0.284871
# 14            (3rd, No)            (Adult)            0.239891
# 15          (Male, 3rd)               (No)            0.231713
# 16            (3rd, No)             (Male)            0.239891
# 17          (Male, 3rd)            (Adult)            0.231713
# 18         (Adult, 3rd)             (Male)            0.284871
# 19   (Male, Adult, 3rd)               (No)            0.209905
# 20      (Male, 3rd, No)            (Adult)            0.191731
# 21     (Adult, 3rd, No)             (Male)            0.216265
# 22          (Male, 3rd)        (Adult, No)            0.231713
# 23            (3rd, No)      (Male, Adult)            0.239891
# 24             (Female)            (Adult)            0.213539
# 25             (Female)              (Yes)            0.213539
# 26      (Female, Adult)              (Yes)            0.193094
# 27        (Female, Yes)            (Adult)            0.156293
# 28                (1st)            (Adult)            0.147660
# 29                (2nd)            (Adult)            0.129487
# 30               (Crew)            (Adult)            0.402090
# 31               (Crew)             (Male)            0.402090
# 32               (Crew)               (No)            0.402090
# 33         (Male, Crew)            (Adult)            0.391640
# 34        (Adult, Crew)             (Male)            0.402090
0.603816  0.304407    0.757062  1.253795  0.061619    1.630802
# 49            0.950477  0.297138    0.919831  0.967757 -0.009900    0.617734
# 50            0.950477  0.153567    0.920981  0.968967 -0.004918    0.626721
#
#     zhangs_metric
# 0        0.061028
# 1        0.263149
# 2        0.659783
# 3        0.436144
# 4        0.046906
# 5        0.621823
# 6        0.064404
# 7        0.429921
# 8        0.697935
# 9        0.467023
# 10       0.139592
# 11      -0.115514
# 12      -0.093712
# 13       0.151418
# 14      -0.066686
# 15       0.236717
# 16       0.021039
# 17      -0.060217
# 18      -0.086060
# 19       0.242806
# 20      -0.043136
# 21       0.041690
# 22       0.180935
# 23      -0.042006
# 24      -0.061028
# 25       0.710327
# 26       0.700873
# 27      -0.039500
# 28       0.037128
# 29      -0.041697
# 30       0.082827
# 31       0.322047
# 32       0.183616
# 33       0.081404
# 34       0.322047
# 35       0.371976
# 36       0.183616
# 37       0.071335
# 38       0.235577
# 39       0.212110
# 40       0.302519
# 41       0.303418
# 42       0.212110
# 43       0.071195
# 44       0.302519
# 45       0.262074
# 46       0.303418
# 47       0.344592
# 48       0.338549
# 49      -0.046906
# 50      -0.037013

# %%
final_rules = rules[rules['consequents'].apply
                       (lambda x: len(x) == 1 and 
                        ('Yes' in x or 'No' in x))]
final_rules
# Out:
#             antecedents consequents  antecedent support  consequent support  \
# 2                (Male)        (No)            0.786461            0.676965
# 5         (Male, Adult)        (No)            0.757383            0.676965
# 10                (3rd)        (No)            0.320763            0.676965
# 13         (Adult, 3rd)        (No)            0.284871            0.676965
# 15          (Male, 3rd)        (No)            0.231713            0.676965
# 19   (Male, Adult, 3rd)        (No)            0.209905            0.676965
# 25             (Female)       (Yes)            0.213539            0.323035
# 26      (Female, Adult)       (Yes)            0.193094            0.323035
# 32               (Crew)        (No)            0.402090            0.676965
# 36        (Adult, Crew)        (No)            0.402090            0.676965
# 39         (Male, Crew)        (No)            0.391640            0.676965
# 42  (Male, Adult, Crew)        (No)            0.391640            0.676965
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 2   0.619718    0.787984  1.163995  0.087312    1.523634       0.659783
# 5   0.603816    0.797241  1.177669  0.091095    1.593193       0.621823
# 10  0.239891    0.747875  1.104747  0.022745    1.281251       0.139592
# 13  0.216265    0.759171  1.121433  0.023418    1.341344       0.151418
# 15  0.191731    0.827451  1.222295  0.034870    1.872135       0.236717
# 19  0.175829    0.837662  1.237379  0.033731    1.989896       0.242806
# 25  0.156293    0.731915  2.265745  0.087312    2.525187       0.710327
# 26  0.143571    0.743529  2.301699  0.081195    2.639542       0.700873
# 32  0.305770    0.760452  1.123325  0.033569    1.348519       0.183616
# 36  0.305770    0.760452  1.123325  0.033569    1.348519       0.183616
# 39  0.304407    0.777262  1.148157  0.039280    1.450292       0.212110
# 42  0.304407    0.777262  1.148157  0.039280    1.450292       0.212110
